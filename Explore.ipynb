# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
pd.set_option('future.no_silent_downcasting', True)

# %%
df1=pd.read_excel("data-raw/S1/File 1-1.xlsx")
df2=pd.read_csv("data-raw/S2/File 2-1.csv")
df3=pd.read_excel("data-raw/S3/File 3-1.xlsx")

# %%
df1.info()
df2.info()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity Name         50 non-null     object
#  1   Sector-Category       50 non-null     object
#  2   Unit                  50 non-null     object
#  3   Emmision (kgCO2e)     50 non-null     float64
#  4   kgCO2                 50 non-null     float64
#  5   kgCH4                 50 non-null     float64
#  6   kgN2O                 50 non-null     object
#  7   Assesment Report      50 non-null     object
#  8   Scope                 50 non-null     int64
#  9   Life Cylce Assesment  50 non-null     object
#  10  Validity Year         50 non-null     int64
#  11  Validity Region       50 non-null     object
#  12  Source                50 non-null     object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 5.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity Name         30 non-null     object
#  1   Sector                30 non-null     object
#  2   Category              30 non-null     object
#  3   Unit                  30 non-null     object
#  4   kgCO2e                30 non-null     float64
#  5   kgCO2                 30 non-null     float64
#  6   kgCH4                 0 non-null      float64
#  7   kgN2O                 24 non-null     float64
#  8   Assesment Report      30 non-null     object
#  9   Scope                 30 non-null     int64
#  10  Life Cylce Assesment  30 non-null     object
#  11  Validity Year         30 non-null     int64
#  12  Validity Region       30 non-null     object
#  13  Source                30 non-null     object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 3.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Activity Name     50 non-null     object
#  1   Unit              50 non-null     object
#  2   kgCO2e            50 non-null     float64
#  3   kgCO2             50 non-null     float64
#  4   kgCH4             50 non-null     float64
#  5   kgN2O             46 non-null     float64
#  6   Assesment Report  50 non-null     object
#  7   Scope             50 non-null     object
#  8   LCA               50 non-null     object
#  9   Sector            50 non-null     object
#  10  Category          50 non-null     object
#  11  Year Valid From   50 non-null     int64
#  12  Region            50 non-null     object
#  13  Source            50 non-null     object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 5.6+ KB

# %%
df1.sample(1)
# Out:
#                                         Activity Name        Sector-Category  \
# 29  North Europe to-from North America WC - Contai...  Transport/Sea Freight
#
#      Unit   Emmision (kgCO2e)     kgCO2     kgCH4         kgN2O  \
# 29  TEU-km          16.222096  4.205493  0.445059  not-supplied
#
#    Assesment Report  Scope              Life Cylce Assesment  Validity Year  \
# 29              AR6      2  primary_production-transport-use           2023
#
#    Validity Region Source
# 29          GLOBAL     S1

# %% [markdown]
# ## Observations
#
# - Different file_type -> data comming from different sources (S1,S2,S3)
# - Different number of columns  -> S1 has 12 others 13 -> Sector-Category (S1) vs Sector and Category (S2, S3)
# - Different naming of columns:
#     - Emmision (kgCO2e) (S1) vs kgCO2e (S2, S3)
#     - LCA (S3) vs Life Cylce Assesment (S1, S2)
#     - Year Valid From (S3) vs Validity Year (S2)   -> We assume they mean the same
#     - Region (S3) vs Validity Region (S1, S2)
#
# - Emissions have missing values and values like  'not-supplied', 'not_supplied' -> we make them np.nan
# - some categorical columns have missing values like: 'Unknown', 'unknown' -> we make them None/ NULL
# - Data types are different -> best data_type for each column?
#
#
# - activity_name: can have duplicated values -> no primary key
# - sector, category, unit, scope, lca: can have "duplicates" like Transport vs transport... activity_name could also have it but maybe not worth changing
#
#
# ## Questions/Asumptions
#
# - We need more domain knowledge to understand relations between columns
# - Who is going to use the database? for what?
# - What is the priority WRITE vs READ?  (Norm vs Denorm)
# - How specific should region be? continent, contry, state....
# - For the units? probably could include conversion factors
# - How much do we know from the source? AWS/GCP, API, email, file type, contact
# - Activity looks like it has a direct relation with sector and category
# - Simple star schema no need to overcomplicate
# - Fact table from emissions (numerical). Dimension tables: activities, region, sources, units...
#
# # Review Process
#
# Create specific tables for the reviewing process in the schema.
#
# - Tables for status, users, change_requests
# - Users can have different roles (editor, reviewer, admin....)
#
# ## Process flow
#
# By default all entries have the status 'pending_review'
#
# 1. User identifies a change/error/issue with an emission factor
# 2. User can submit a request with:
#     - emission_factor_id
#     - proposed_changes in JSON form
#     - requested_by_id
#     - requested_at: This one is set automatically
# 3. Another user reviews the request
#     - reviewed_by_id
#     - adds review_comments
#     - changes to table according to JSON
#     - changes status to 'aprroved' or 'rejected'

# %%
paths = ["data-raw/S1/File 1-1.xlsx","data-raw/S2/File 2-1.csv", "data-raw/S3/File 3-1.xlsx"]
# Standardize column names
STANDARD_COLUMNS = ['activity_name', 'sector', 'category', 'unit', 'kgco2e', 'kgco2', 'kgch4', 'kgn2o',
       'assesment_report', 'scope', 'lca', 'validity_year',
       'region', 'source', 'file_type']

all_data = []
for file_path in paths:
    extension = file_path.split(".")[1]
    source = file_path.split("/")[1]
    if extension == "csv":
        df = pd.read_csv(file_path)
    else:
        df = pd.read_excel(file_path)
    
    # Split Sector-Category
    if source == "S1":   
        df[['Sector', 'Category']] = df['Sector-Category'].str.split('/', expand=True)
        df.drop(['Sector-Category'], axis=1, inplace=True)

    # Standarize columns
    df.columns = df.columns.str.lower().str.rstrip().str.replace(' ', '_').str.replace('-', '_')
    df = df.rename(columns={
        'emmision_(kgco2e)': 'kgco2e',
        'life_cylce_assesment': 'lca',
        'year_valid_from': 'validity_year',
        'validity_region': 'region'
    })
    # add source file and file_type
    df['source'] = source
    df[ 'file_type'] = extension

    # clean strings to avoid duplicates like Transport and transport
    for column in ['sector', 'category', 'unit','scope', 'lca']:      # Open question: activity_name ????
        df[column] = df[column].apply(lambda x: str(x).lower().rstrip())
    
    # clean missing values
    df.replace(['unknown', 'Unknown'], None, inplace=True)
    df.replace(["not_supplied", "not-supplied"], np.nan, inplace=True)

    df = df.reindex(columns=STANDARD_COLUMNS)
    all_data.append(df)
    
combined_df = pd.concat(all_data)
# Out:
# /tmp/ipykernel_67281/785940117.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat(all_data)

# %%
print(combined_df.columns)
combined_df.sample(2)
# Out:
# Index(['activity_name', 'sector', 'category', 'unit', 'kgco2e', 'kgco2',
#        'kgch4', 'kgn2o', 'assesment_report', 'scope', 'lca', 'validity_year',
#        'region', 'source', 'file_type'],
#       dtype='object')
#                                         activity_name     sector  \
# 39  North Europe to-from Mediterranean/Black Sea -...  transport
# 25      Articulated truck 44-60t - Container - Diesel  transport
#
#         category      unit     kgco2e     kgco2     kgch4  kgn2o  \
# 39   sea freight    teu-km  18.333037  8.738967  0.355336    NaN
# 25  road freight  tonne-km  12.391327  2.071839  0.382203    NaN
#
#    assesment_report scope                           lca  validity_year  \
# 39              AR6     2  primary_production-transport           2023
# 25              AR6     2                           use           2023
#
#     region source file_type
# 39  GLOBAL     S1      xlsx
# 25  GLOBAL     S1      xlsx

# %%
combined_df["assesment_report"]
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df1=all_data[0]
#df1.info()
df2=all_data[1]
#df2.info()
df3=all_data[2]
#df3.info()
display(df1.sample())
display(df2.sample())
display(df3.sample())
# Out:
#                            activity_name     sector     category      unit  \
# 17  Other liquids tankers <999 dwt - MDO  Transport  Sea Freight  tonne-km
#
#        kgco2e    kgco2     kgch4 kgn2o assesment_report  scope  lca  \
# 17  30.988433  4.01066  0.999177   NaN              AR6      2  NaN
#
#     validity_year  region source
# 17           2023  GLOBAL     S1
#                       activity_name  sector category unit    kgco2e     kgco2  \
# 6  Sub-bituminous coal - industrial  energy     fuel   Kg  2.775364  2.670836
#
#    kgch4     kgn2o assesment_report  scope  lca  validity_year region source
# 6    NaN  0.000418              AR4      2  NaN           2023     GB     S2
#                                      activity_name sector       category  \
# 21  PP waste disposal  (incl. forming) - open-loop  waste  Plastic Waste
#
#      unit      kgco2e     kgco2     kgch4     kgn2o assesment_report scope  \
# 21  tonne  141.393414  9.387046  4.889052  0.000008              AR4  None
#
#             lca  validity_year region source
# 21  end_of_life           2021  US-TX     S3

# %%
for x in ["scope","assesment_report", 'source']:
    print(combined_df[x].value_counts())
    print("########")
# Out:
# scope
# 2    62
# 1    11
# 3     7
# Name: count, dtype: int64
# ########
# assesment_report
# AR4    80
# AR6    50
# Name: count, dtype: int64
# ########
# source
# S1    50
# S3    50
# S2    30
# Name: count, dtype: int64
# ########

# %%
df_copy = combined_df.copy()
for column in ['activity_name']:
        df_copy[column] = df_copy[column].apply(lambda x: str(x).lower().rstrip())

df_copy.activity_name.value_counts()
#combined_df.lca.value_counts()
# Out:
# activity_name
# hotel stay (3 star)                                                                                 3
# liquefied petroleum gas lpg - transport                                                             2
# liquefied gas tanker 50000-99999 cbm - mdo                                                          2
# container ship - reefer (refrigerated)                                                              1
# europe (north & med) to- from oceania (via suez / via panama) - container ship (dry)                1
# freight logistics - transshipment - mixed                                                           1
# asia to-from africa - container ship - reefer (refrigerated)                                        1
# rigid truck 7.5-12t - average/mixed load - diesel                                                   1
# rail freight (electric traction) - trailer only on train - distribution losses                      1
# north america ec/gulf/wc to-from middle east/india - container ship - reefer (refrigerated)         1
# road freight - specialized                                                                          1
# general cargo 10000-19999 dwt - vlsfo                                                               1
# asia to-from north america wc - container ship - reefer (refrigerated)                              1
# rigid truck 3.5-7.5t - average/mixed load - diesel                                                  1
# bulk carrier 60000-99999 dwt - vlsfo                                                                1
# ro-ro 10000-14999 dwt - hfo                                                                         1
# asia to-from north america ec / gulf - container ship (dry)                                         1
# other liquids tankers <999 dwt - mdo                                                                1
# other liquids tankers >1000 dwt - vlsfo                                                             1
# europe (north & med) to- from africa - container ship - reefer (refrigerated)                       1
# intra mediterranean/ black sea - container ship - reefer (refrigerated)                             1
# articulated truck 60-72t - container - diesel                                                       1
# articulated truck <40t si engine - container transport - lng                                        1
# intra middle east/india - container ship - reefer (refrigerated)                                    1
# liquefied gas tanker <49999 cbm - vlsfo                                                             1
# articulated truck 44-60t - container - diesel                                                       1
# road freight - ltl/dry van                                                                          1
# oil tanker 10000-19999 dwt - mdo                                                                    1
# ro-ro 5000-9999 dwkt - vlsfo                                                                        1
# air freight (<1500 km) - freighter - rp1678                                                         1
# north europe to-from north america wc - container ship - reefer (refrigerated)                      1
# articulated truck <34t - average/mixed load - diesel                                                1
# panama trade - container ship (dry)                                                                 1
# liquefied gas tanker 100000-199999 cbm - mdo                                                        1
# refrigerated bulk >10000 dwt - hfo                                                                  1
# liquefied gas tanker >200000 cbm - mdo                                                              1
# road freight - refrigerated                                                                         1
# rail freight (diesel traction) - container transport                                                1
# liquefied gas tanker >200000 cbm - vlsfo                                                            1
# north europe to-from mediterranean/black sea - container ship - reefer (refrigerated)               1
# chemical tanker >40000 dwt - hfo                                                                    1
# other liquids tankers <999 dwt - hfo                                                                1
# freight logistics - transshipment - ambient                                                         1
# general cargo 5000-9999 dwt - hfo                                                                   1
# se asia to-from ne asia - container ship (dry)                                                      1
# oil tanker >200000 dwt - vlsfo                                                                      1
# other - container ship (dry)                                                                        1
# trans-atlantic - container ship (dry)                                                               1
# intra south america - container ship - reefer (refrigerated)                                        1
# liquefied gas tanker 50000-99999 cbm - vlsfo                                                        1
# non municipal waste - biological (sludge)                                                           1
# diesel hybrid car (rental)                                                                          1
# diesel hybrid bus (<7.5t)                                                                           1
# petrol phev car                                                                                     1
# battery ev bus (<12t)                                                                               1
# sub-bituminous coal - industrial                                                                    1
# international long-haul flight - with rf effect                                                     1
# office waste - waste to landfill without gas recovery                                               1
# paper - waste to landfill without gas recovery                                                      1
# diesel phev lcv (<1350cc) - electricity consumption post-2015                                       1
# garden - waste to landfill with gas recovery                                                        1
# oil tanker 20000-59999 dwt - hfo                                                                    1
# petrol lcv (2000-3000cc) post-2015                                                                  1
# electric bus                                                                                        1
# lcv - phev (petrol) - electricity consumption (>3000 cc) post-2015                                  1
# taxi (average) post-2015                                                                            1
# diesel bus (>12t)                                                                                   1
# domestic coastal freight - oil products tanker - meg 2022                                           1
# metropolitan railway diesel                                                                         1
# wood - industrial                                                                                   1
# vehicle transport 0 - 3999 ceu                                                                      1
# lcv - petrol hybrid - default factor                                                                1
# lignite coal - industrial                                                                           1
# water supply                                                                                        1
# hgv diesel (25 - 30t) post-2015                                                                     1
# lcv - phev (petrol) - petrol consumption (>3000 cc) post-2015                                       1
# general cargo - 5000 - 9999dwt                                                                      1
# general cargo < 4999dwt                                                                             1
# motor vehicle brakes and brake systems                                                              1
# flour and other grain mill products                                                                 1
# boats and personal watercraft                                                                       1
# marine fuel oil                                                                                     1
# eggs cardboard box                                                                                  1
# paper waste for treatment: incineration                                                             1
# aluminium - alloys - hollow profiles                                                                1
# grey clinker                                                                                        1
# gcp - embodied emissions - c2-standard-60 - cascade lake                                            1
# biogasoline                                                                                         1
# gasoline passenger cars (1983 models)                                                               1
# stainless steel - flat-rolled <600mm hot-rolled                                                     1
# vegetables / fruits / nuts                                                                          1
# other social services                                                                               1
# distribution and trade of electricity (services)                                                    1
# diesel phev car (2000-3000cc) - electricity consumption                                             1
# food waste for treatment: composting and land application                                           1
# translation and interpretation services                                                             1
# rubber and plastic products                                                                         1
# household residual waste disposal (composting)                                                      1
# electricity supplied from nuclear power plant                                                       1
# pp waste disposal  (incl. forming) - open-loop                                                      1
# water transportation support / maintenance and repair services                                      1
# hogs                                                                                                1
# hotel stay                                                                                          1
# tires                                                                                               1
# rigid truck (7.5 t - 12 t) - average / mixed load - cng                                             1
# ethane                                                                                              1
# artic truck 34 - 40 t - container transport - refrig/temp controlled - diesel 5% biodiesel blend    1
# plastic resins                                                                                      1
# pet waste (incl. forming) disposal - closed-loop                                                    1
# r403a                                                                                               1
# phev car (medium) - uk electricity t&d for evs                                                      1
# petrol car (dual-purpose 4x4) - passenger vehicles & travel land                                    1
# hgv refrigerated (all diesel) - rigid (>17 tonnes) - average laden - managed assets (vehicles)      1
# fugitive methane emissions from coal mining                                                         1
# sugar cane/sugar beet                                                                               1
# biopropane                                                                                          1
# plastics waste disposal - combustion                                                                1
# furniture/other manufactured goods (not elsewhere specified)                                        1
# hydrogen passenger car large                                                                        1
# basic iron and steel and of ferroalloys and first products thereof                                  1
# white spirit/sbp                                                                                    1
# cold-rolled iron or steel products                                                                  1
# iron non-alloy steel - flat-rolled <600mm clad plated coated                                        1
# other professional / scientific and technical services                                              1
# nonferrous metal die-casting foundries                                                              1
# radio stations                                                                                      1
# Name: count, dtype: int64

# %%
combined_df[["activity_name"]]
# Out:
#                                         activity_name
# 0   Europe (North & Med) to- from Oceania (via Sue...
# 1   Rigid truck 3.5-7.5t - Average/mixed load - Di...
# 2              Container ship - reefer (refrigerated)
# 3           Freight logistics - transshipment - mixed
# 4   Asia to-from North America WC - Container ship...
# 5         Air freight (<1500 km) - freighter - RP1678
# 6   Asia to-from Africa - Container ship - reefer ...
# 7   Rigid truck 7.5-12t - Average/mixed load - Diesel
# 8   Rail freight (electric traction) - trailer onl...
# 9   North America EC/Gulf/WC to-from Middle East/I...
# 10                         Road freight - Specialized
# 11              General cargo 10000-19999 dwt - VLSFO
# 12                       Ro-Ro 5000-9999 dwkt - VLSFO
# 13                   Oil tanker 20000-59999 dwt - HFO
# 14               Bulk carrier 60000-99999 dwt - VLSFO
# 15                        Ro-Ro 10000-14999 dwt - HFO
# 16  Asia to-from North America EC / Gulf - Contain...
# 17               Other liquids tankers <999 dwt - MDO
# 18            Other liquids tankers >1000 dwt - VLSFO
# 19  Europe (North & Med) to- from Africa - Contain...
# 20  Intra Mediterranean/ Black Sea - Container shi...
# 21      Articulated truck 60-72t - Container - Diesel
# 22  Articulated truck <40t SI engine - Container t...
# 23  Intra Middle East/India - Container ship - ree...
# 24            Liquefied gas tanker <49999 cbm - VLSFO
# 25      Articulated truck 44-60t - Container - Diesel
# 26                         Road freight - LTL/Dry Van
# 27                   Oil tanker 10000-19999 dwt - MDO
# 28  Articulated truck <34t - Average/mixed load - ...
# 29  North Europe to-from North America WC - Contai...
# 30       Liquefied gas tanker 100000-199999 cbm - MDO
# 31  Rail freight (diesel traction) - container tra...
# 32                Panama Trade - Container ship (dry)
# 33                 Refrigerated bulk >10000 dwt - HFO
# 34             Liquefied gas tanker >200000 cbm - MDO
# 35         Liquefied gas tanker 50000-99999 cbm - MDO
# 36                        Road freight - Refrigerated
# 37                     Oil tanker >200000 dwt - VLSFO
# 38           Liquefied gas tanker >200000 cbm - VLSFO
# 39  North Europe to-from Mediterranean/Black Sea -...
# 40                   Chemical tanker >40000 dwt - HFO
# 41               Other liquids tankers <999 dwt - HFO
# 42        Freight logistics - transshipment - ambient
# 43                  General cargo 5000-9999 dwt - HFO
# 44         Liquefied gas tanker 50000-99999 cbm - MDO
# 45     SE Asia to-from NE Asia - Container ship (dry)
# 46                       Other - Container ship (dry)
# 47              Trans-Atlantic - Container ship (dry)
# 48       Liquefied gas tanker 50000-99999 cbm - VLSFO
# 49  Intra South America - Container ship - reefer ...
# 0           Non municipal waste - Biological (sludge)
# 1                          Diesel hybrid car (rental)
# 2                           Diesel hybrid bus (<7.5t)
# 3             Liquefied petroleum gas LPG - transport
# 4                                     Petrol PHEV car
# 5                               Battery EV bus (<12t)
# 6                    Sub-bituminous coal - industrial
# 7     International long-haul flight - with RF effect
# 8   Office waste - waste to landfill without gas r...
# 9      Paper - waste to landfill without gas recovery
# 10  Diesel PHEV LCV (<1350cc) - electricity consum...
# 11       Garden - waste to landfill with gas recovery
# 12                 Petrol LCV (2000-3000cc) post-2015
# 13                                       Electric Bus
# 14                           Taxi (average) post-2015
# 15  LCV - PHEV (Petrol) - Electricity consumption ...
# 16                                  Wood - industrial
# 17                                  Diesel bus (>12t)
# 18  Domestic coastal freight - Oil products tanker...
# 19                        Metropolitan Railway Diesel
# 20                            General cargo < 4999dwt
# 21                     Vehicle transport 0 - 3999 CEU
# 22               LCV - Petrol hybrid - default factor
# 23                          Lignite coal - industrial
# 24                                       Water supply
# 25            Liquefied petroleum gas LPG - transport
# 26                    HGV diesel (25 - 30t) post-2015
# 27  LCV - PHEV (Petrol) - Petrol consumption (>300...
# 28                     General cargo - 5000 - 9999dwt
# 29  Diesel PHEV car (2000-3000cc) - electricity co...
# 0              Motor vehicle brakes and brake systems
# 1                 Flour and other grain mill products
# 2                       Boats and personal watercraft
# 3                                     Marine fuel oil
# 4                                  Eggs cardboard box
# 5             Paper waste for treatment: incineration
# 6                Aluminium - alloys - hollow profiles
# 7                                        Grey clinker
# 8   GCP - Embodied emissions - c2-standard-60 - Ca...
# 9                                         Biogasoline
# 10              Gasoline passenger cars (1983 models)
# 11    Stainless steel - flat-rolled <600mm hot-rolled
# 12                         Vegetables / fruits / nuts
# 13                              Other social services
# 14   Distribution and trade of electricity (services)
# 15  Food waste for treatment: composting and land ...
# 16            Translation and interpretation services
# 17     Household residual waste disposal (composting)
# 18                        Rubber and plastic products
# 19                                               Hogs
# 20      Electricity supplied from nuclear power plant
# 21     PP waste disposal  (incl. forming) - open-loop
# 22  Water transportation support / maintenance and...
# 23                                              R403A
# 24                                         Hotel stay
# 25                                              Tires
# 26  Rigid truck (7.5 t - 12 t) - average / mixed l...
# 27                                             Ethane
# 28  Artic truck 34 - 40 t - Container transport - ...
# 29                                     Plastic resins
# 30   PET waste (incl. forming) disposal - closed-loop
# 31     PHEV car (medium) - UK electricity T&D for EVs
# 32  Petrol car (dual-purpose 4X4) - Passenger vehi...
# 33                                Hotel stay (3 star)
# 34                                Hotel stay (3 star)
# 35  HGV refrigerated (all diesel) - Rigid (>17 ton...
# 36        Fugitive methane emissions from coal mining
# 37                              Sugar cane/sugar beet
# 38                                         Biopropane
# 39               Plastics waste disposal - combustion
# 40  Furniture/other manufactured goods (not elsewh...
# 41                       Hydrogen passenger car large
# 42  Basic iron and steel and of ferroalloys and fi...
# 43                                   White spirit/SBP
# 44                 Cold-rolled iron or steel products
# 45  Iron non-alloy steel - flat-rolled <600mm clad...
# 46  Other professional / scientific and technical ...
# 47             Nonferrous metal die-casting foundries
# 48                                Hotel stay (3 star)
# 49                                     Radio stations

# %%
combined_df.activity_name.value_counts()
combined_df[combined_df["activity_name"].isin(["Hotel stay (3 star)", "Liquefied petroleum gas LPG - transport", "Liquefied gas tanker 50000-99999 cbm - MDO"])]
# Out:
#                                  activity_name                         sector  \
# 35  Liquefied gas tanker 50000-99999 cbm - MDO                      Transport
# 44  Liquefied gas tanker 50000-99999 cbm - MDO                      Transport
# 3      Liquefied petroleum gas LPG - transport                         energy
# 25     Liquefied petroleum gas LPG - transport                         energy
# 33                         Hotel stay (3 star)  restaurants and accommodation
# 34                         Hotel stay (3 star)  restaurants and accommodation
# 48                         Hotel stay (3 star)  restaurants and accommodation
#
#          category        unit      kgco2e     kgco2     kgch4     kgn2o  \
# 35    Sea Freight    tonne-km   23.390201  4.510120  0.699262       NaN
# 44    Sea Freight    tonne-km   16.304026  4.385202  0.441438       NaN
# 3            fuel           L    2.859979  2.766725       NaN  0.000373
# 25           fuel           L    2.094755  2.094755       NaN       NaN
# 33  Accommodation  room-night   81.138327  2.780048  2.902158       NaN
# 34  Accommodation  room-night   34.752395  8.883738  0.958047  0.000006
# 48  Accommodation  room-night  102.946649  2.433086  3.722682  0.000005
#
#    assesment_report scope   lca  validity_year  region source
# 35              AR6     2   NaN           2023  GLOBAL     S1
# 44              AR6     2   NaN           2023  GLOBAL     S1
# 3               AR4     1   NaN           2023      US     S2
# 25              AR4     3   NaN           2020      DE     S2
# 33              AR4  None  None           2022   US-MN     S3
# 34              AR4  None  None           2022   US-TX     S3
# 48              AR4  None  None           2022   US-TX     S3

# %%
combined_df[combined_df["activity_name"].isin(["Hotel stay (3 star)", "Liquefied petroleum gas LPG - transport"])].to_csv("test1.csv", index=False)

# %%
combined_df.sample(5).to_csv("test2.csv", index=False)

# %%
def clean_s1(file_name):
    """Clean and standardize file 1"""
    df = pd.read_excel(f"data-raw/S1/{file_name}")
    
    # Split Sector-Category
    df[['Sector', 'Category']] = df['Sector-Category'].str.split('/', expand=True)
    
    # Standardize column names
    df = df.rename(columns={
        'Emmision (kgCO2e)': 'kgCO2e',
        'Life Cylce Assesment': 'LCA',
        'Validity Year': 'Validity_Year',
        'Validity Region': 'Region'
    })
    
    # Handle 'not-supplied' values
    df = df.replace('not-supplied', np.nan)
    
    return df

def clean_s2(file_name):
    """Clean and standardize file 2"""
    df = pd.read_csv(f"data-raw/S2/{file_name}")
    
    # Rename columns
    df = df.rename(columns={
        'Life Cylce Assesment': 'LCA',
        'Validity Year': 'Validity_Year',
        'Validity Region': 'Region'
    })
    
    return df

def clean_s3(file_path):
    """Clean and standardize file 3"""
    df = pd.read_excel(f"data-raw/S3/{file_name}")
    
    # Rename columns
    df = df.rename(columns={
        'Year Valid From': 'Validity_Year',
        'Region': 'Region'
    })
    
    # Handle 'Unknown' scope
    df['Scope'] = df['Scope'].replace('Unknown', None)
    
    return df
# Out:
# file1 12 ['Activity Name', 'Sector-Category', 'Unit ', 'Emmision (kgCO2e)', 'kgCO2', 'kgCH4', 'kgN2O', 'Assesment Report', 'Scope', 'Life Cylce Assesment', 'Validity Year', 'Validity Region']
# file2 13 ['Activity Name', 'Sector', 'Category', 'Unit ', 'kgCO2e', 'kgCO2', 'kgCH4', 'kgN2O', 'Assesment Report', 'Scope', 'Life Cylce Assesment', 'Validity Year', 'Validity Region']
# file3 13 ['Activity Name', 'Unit ', 'kgCO2e', 'kgCO2', 'kgCH4', 'kgN2O', 'Assesment Report', 'Scope', 'LCA', 'Sector', 'Category', 'Year Valid From', 'Region']
#                        Activity Name        Sector-Category     Unit   \
# 40  Chemical tanker >40000 dwt - HFO  Transport/Sea Freight  tonne-km
#
#     Emmision (kgCO2e)    kgCO2     kgCH4         kgN2O Assesment Report  \
# 40           6.663576  4.81487  0.068471  not-supplied              AR6
#
#     Scope              Life Cylce Assesment  Validity Year Validity Region
# 40      2  primary_production-transport-use           2023          GLOBAL

# %%
CREATE TABLE Emissions (
    emission_id SERIAL PRIMARY KEY,
    activity_id INT REFERENCES Activities(activity_id),
    kgco2e FLOAT,
    kgco2 FLOAT,
    kgch4 FLOAT,
    kgn2o FLOAT,
    assessment_report VARCHAR(50),
    scope VARCHAR(50),
    lca VARCHAR(50),
    validity_year INT,
    region VARCHAR(100),
    source VARCHAR(50)
);

# %%
-- Main emission factors table
CREATE TABLE emission_factors (
    emission_factor_id SERIAL PRIMARY KEY,
    activity_id INTEGER NOT NULL REFERENCES activities(activity_id),
    unit_id INTEGER NOT NULL REFERENCES units(unit_id),
    region_id INTEGER NOT NULL REFERENCES regions(region_id),
    source_id INTEGER NOT NULL REFERENCES sources(source_id),
    scope scope_type,
    assessment_report assessment_report_type,
    validity_year INTEGER,
    lca BOOLEAN,
    kgco2e DECIMAL(20,10),
    kgco2 DECIMAL(20,10),
    kgch4 DECIMAL(20,10),
    kgn2o DECIMAL(20,10),

    created_at TIMESTAMP WITH TIME ZONE DEFAULT CURRENT_TIMESTAMP,
    updated_at TIMESTAMP WITH TIME ZONE DEFAULT CURRENT_TIMESTAMP,
    
    CONSTRAINT emission_factors_validity_year_check CHECK (validity_year > 1900),
    CONSTRAINT emission_factors_date_check CHECK (valid_until IS NULL OR valid_until > valid_from)
);
